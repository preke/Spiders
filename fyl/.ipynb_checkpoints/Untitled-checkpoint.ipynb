# %%
# coding:utf-8
import requests
import hashlib
import urllib2
import urllib
import urlparse
from bs4 import BeautifulSoup

def crawl(url):
    user_agent = 'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.86 Safari/537.36'
    headers = {'User-Agent': user_agent}
    request = urllib2.Request(url, headers=headers)
    response = urllib2.urlopen(request) 
    html = response.read()
    soup = BeautifulSoup(html, from_encoding='utf-8')
    return soup

# %%
soup = crawl('http://webportal2-autocog.rhcloud.com/search/?q=com.Birthday_Countdown_Alarm_Clock_118071.apk')
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file C:\Program Files\Anaconda2\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
# soup
ps = soup.find('script', type='text/javascript').get_text()
print ps
# Out:
#
# 	function ShowPopup(elemid)
# 	{
#
# 	var hp = document.getElementById('next'+elemid);
#
# 	if (hp.style.display=="none"){
#
# 		hp.style.display = "";
# 	}
# 	else{
# 		hp.style.display = "none";
# 	}
# 	return false;
#
# 	}
#
#
# 	function CreateTable()
# 	{
# 	var tablecontents = "";
# 	var i = 0;
# 	var j = 0;
# 	tablecontents = "<table class='fixed' border='1'>";
# 	tablecontents +=  "<col width='400px' />"
# 	tablecontents +=  "<col width='800px' />"
# 	tablecontents += "<thead>";
# 	tablecontents += "<tr>";
# 	tablecontents += "<th> AutoCog </th>";
# 	tablecontents += "<th class='turn_red'> Questionable Permissions </th>";
# 	tablecontents += "</tr>";
# 	tablecontents += "</thead>";
#
# 	tablecontents += "";
#
# 	tablecontents += "<tr id=\"tabitem"+ i++ +"\" onclick='ShowPopup(this.id);'>";
#
# 	tablecontents += "<td>com.Birthday_Countdown_Alarm_Clock_118071.apk</td>";
# 	tablecontents += "<td class='turn_red'>WRITE_CONTACTS,READ_CALENDAR</td>";
#
# 	tablecontents += "</tr>";
#
# 	tablecontents += "<tr>";
# 	tablecontents += "<td colspan='2' id=\"nexttabitem"+ j++ +"\" style='display:none; position:relative;'>";
# 	tablecontents += "";
#
# 	var change = "It will show you the person&#39;s name, and left days to his/her birthday";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>It will show you the person&#39;s name, and left days to his/her birthday</p>";
# 	}
# 	else{
# 	tablecontents += "<p>It will show you the person&#39;s name, and left days to his/her birthday</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "location and security";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>location and security</p>";
# 	}
# 	else{
# 	tablecontents += "<p>location and security</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Click the following buttons to deactivate";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Click the following buttons to deactivate</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Click the following buttons to deactivate</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Birthday countdown days show";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Birthday countdown days show</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Birthday countdown days show</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Alarm clock for birthday";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Alarm clock for birthday</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Alarm clock for birthday</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Press the new button in the main interface";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Press the new button in the main interface</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Press the new button in the main interface</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "How to remember the person&#39;s birthday though Birthday Countdown Alarm Clock(READ_CONTACTS)";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>How to remember the person&#39;s birthday though Birthday Countdown Alarm Clock(READ_CONTACTS)</p>";
# 	}
# 	else{
# 	tablecontents += "<p>How to remember the person&#39;s birthday though Birthday Countdown Alarm Clock(READ_CONTACTS)</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "BEFORE DOWNLOAD";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>BEFORE DOWNLOAD</p>";
# 	}
# 	else{
# 	tablecontents += "<p>BEFORE DOWNLOAD</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "device administration";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>device administration</p>";
# 	}
# 	else{
# 	tablecontents += "<p>device administration</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "This app here is free for all";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>This app here is free for all</p>";
# 	}
# 	else{
# 	tablecontents += "<p>This app here is free for all</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "It is the section you can set the alarm clock and some other display information";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>It is the section you can set the alarm clock and some other display information</p>";
# 	}
# 	else{
# 	tablecontents += "<p>It is the section you can set the alarm clock and some other display information</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Be a nice person and start with Birthday Countdown Alarm Clock";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Be a nice person and start with Birthday Countdown Alarm Clock</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Be a nice person and start with Birthday Countdown Alarm Clock</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "You also can turn on/off alarm, set alarm time, sound and vibration effects";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>You also can turn on/off alarm, set alarm time, sound and vibration effects</p>";
# 	}
# 	else{
# 	tablecontents += "<p>You also can turn on/off alarm, set alarm time, sound and vibration effects</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "You also can have some further operations by long pressing it";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>You also can have some further operations by long pressing it</p>";
# 	}
# 	else{
# 	tablecontents += "<p>You also can have some further operations by long pressing it</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Click to save it and then you will find it in the main interface";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Click to save it and then you will find it in the main interface</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Click to save it and then you will find it in the main interface</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Settings";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Settings</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Settings</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Easy and simple to use";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Easy and simple to use</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Easy and simple to use</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Then you need to deactivate before you uninstall it, otherwise, you cannot uninstall it";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Then you need to deactivate before you uninstall it, otherwise, you cannot uninstall it</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Then you need to deactivate before you uninstall it, otherwise, you cannot uninstall it</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "The things in this application are around with birthday";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>The things in this application are around with birthday</p>";
# 	}
# 	else{
# 	tablecontents += "<p>The things in this application are around with birthday</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Base on android mobile operating system";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Base on android mobile operating system</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Base on android mobile operating system</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Birthday is a day that a person celebrates the anniversary of his or her birth";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Birthday is a day that a person celebrates the anniversary of his or her birth</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Birthday is a day that a person celebrates the anniversary of his or her birth</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Calculate way and date format can be chose in this section, and various options are provided by Birthday Countdown Alarm Clock";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Calculate way and date format can be chose in this section, and various options are provided by Birthday Countdown Alarm Clock</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Calculate way and date format can be chose in this section, and various options are provided by Birthday Countdown Alarm Clock</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Find this app there and uncheck to uninstall";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Find this app there and uncheck to uninstall</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Find this app there and uncheck to uninstall</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Functions introduction";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Functions introduction</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Functions introduction</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Main interface";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Main interface</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Main interface</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "It is also ad-supported which means that you may find icon ads or notification ads in this app(RECEIVE_BOOT_COMPLETED)";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>It is also ad-supported which means that you may find icon ads or notification ads in this app(RECEIVE_BOOT_COMPLETED)</p>";
# 	}
# 	else{
# 	tablecontents += "<p>It is also ad-supported which means that you may find icon ads or notification ads in this app(RECEIVE_BOOT_COMPLETED)</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "This app can be activated by the inside setting button";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>This app can be activated by the inside setting button</p>";
# 	}
# 	else{
# 	tablecontents += "<p>This app can be activated by the inside setting button</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "This application is used to help you to remember the birthday of people who important for you, and it will remind you when the birthday comes(READ_CONTACTS)";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>This application is used to help you to remember the birthday of people who important for you, and it will remind you when the birthday comes(READ_CONTACTS)</p>";
# 	}
# 	else{
# 	tablecontents += "<p>This application is used to help you to remember the birthday of people who important for you, and it will remind you when the birthday comes(READ_CONTACTS)</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Download this app and you will find them out";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Download this app and you will find them out</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Download this app and you will find them out</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Enter into the information, including name, description and birthday";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Enter into the information, including name, description and birthday</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Enter into the information, including name, description and birthday</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Information for person&#39;s birthday";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Information for person&#39;s birthday</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Information for person&#39;s birthday</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Now, download it";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Now, download it</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Now, download it</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "About Uninstall";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>About Uninstall</p>";
# 	}
# 	else{
# 	tablecontents += "<p>About Uninstall</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Menu";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Menu</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Menu</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Thanks for your understanding";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Thanks for your understanding</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Thanks for your understanding</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "With this free app, maybe you can make yourself more popular among your friends";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>With this free app, maybe you can make yourself more popular among your friends</p>";
# 	}
# 	else{
# 	tablecontents += "<p>With this free app, maybe you can make yourself more popular among your friends</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "Features";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Features</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Features</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "setting";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>setting</p>";
# 	}
# 	else{
# 	tablecontents += "<p>setting</p>";
# 	}
# 	tablecontents += "";
#
# 	var change = "You can click them here to check the detail information for the day of his/her birthday, such as will be age, week day and zodiac sign and so on";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>You can click them here to check the detail information for the day of his/her birthday, such as will be age, week day and zodiac sign and so on</p>";
# 	}
# 	else{
# 	tablecontents += "<p>You can click them here to check the detail information for the day of his/her birthday, such as will be age, week day and zodiac sign and so on</p>";
# 	}
# 	tablecontents += "";
# 	tablecontents += "</td>";
# 	tablecontents += "</tr>";
#
#
# 	tablecontents += "";
#
#
# 	tablecontents += "</table>";
# 	document.getElementById("tablespace").innerHTML = tablecontents;
# 	return false;
# 	}
#
#
# 	function Search(txt)
# 	{
# 	if (txt.length==0){
# 	CreateTable();
# 	return false;
# 	}
#
# 	var lowertxt =txt.toLowerCase();
#
# 	var tablecontents = "";
# 	var i = 0;
# 	var j = 0;
# 	tablecontents = "<table class='fixed' border='1'>";
# 	tablecontents +=  "<col width='400px' />"
# 	tablecontents +=  "<col width='800px' />"
# 	tablecontents += "<thead>";
# 	tablecontents += "<tr>";
# 	tablecontents += "<th> AutoCog </th>";
# 	tablecontents += "<th class='turn_red'> Questionable Permissions </th>";
# 	tablecontents += "</tr>";
# 	tablecontents += "</thead>";
#
# 	tablecontents += "";
#
# 	var lowertitle ="com.Birthday_Countdown_Alarm_Clock_118071.apk".toLowerCase();
# 	if ( lowertitle.indexOf(lowertxt) != -1){
#
# 	tablecontents += "<tr id=\"tabitem"+ i++ +"\" onclick='ShowPopup(this.id);'>";
#
# 	tablecontents += "<td>com.Birthday_Countdown_Alarm_Clock_118071.apk</td>";
# 	tablecontents += "<td class='turn_red'>WRITE_CONTACTS,READ_CALENDAR</td>";
#
# 	tablecontents += "</tr>";
#
# 	tablecontents += "<tr>";
# 	tablecontents += "<td colspan='2' id=\"nexttabitem"+ j++ +"\" style='display:none; position:relative;'>";
# 	tablecontents += "";
# 	var change = "It will show you the person&#39;s name, and left days to his/her birthday";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>It will show you the person&#39;s name, and left days to his/her birthday</p>";
# 	}
# 	else{
# 	tablecontents += "<p>It will show you the person&#39;s name, and left days to his/her birthday</p>";
# 	}
# 	tablecontents += "";
# 	var change = "location and security";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>location and security</p>";
# 	}
# 	else{
# 	tablecontents += "<p>location and security</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Click the following buttons to deactivate";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Click the following buttons to deactivate</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Click the following buttons to deactivate</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Birthday countdown days show";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Birthday countdown days show</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Birthday countdown days show</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Alarm clock for birthday";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Alarm clock for birthday</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Alarm clock for birthday</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Press the new button in the main interface";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Press the new button in the main interface</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Press the new button in the main interface</p>";
# 	}
# 	tablecontents += "";
# 	var change = "How to remember the person&#39;s birthday though Birthday Countdown Alarm Clock(READ_CONTACTS)";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>How to remember the person&#39;s birthday though Birthday Countdown Alarm Clock(READ_CONTACTS)</p>";
# 	}
# 	else{
# 	tablecontents += "<p>How to remember the person&#39;s birthday though Birthday Countdown Alarm Clock(READ_CONTACTS)</p>";
# 	}
# 	tablecontents += "";
# 	var change = "BEFORE DOWNLOAD";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>BEFORE DOWNLOAD</p>";
# 	}
# 	else{
# 	tablecontents += "<p>BEFORE DOWNLOAD</p>";
# 	}
# 	tablecontents += "";
# 	var change = "device administration";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>device administration</p>";
# 	}
# 	else{
# 	tablecontents += "<p>device administration</p>";
# 	}
# 	tablecontents += "";
# 	var change = "This app here is free for all";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>This app here is free for all</p>";
# 	}
# 	else{
# 	tablecontents += "<p>This app here is free for all</p>";
# 	}
# 	tablecontents += "";
# 	var change = "It is the section you can set the alarm clock and some other display information";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>It is the section you can set the alarm clock and some other display information</p>";
# 	}
# 	else{
# 	tablecontents += "<p>It is the section you can set the alarm clock and some other display information</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Be a nice person and start with Birthday Countdown Alarm Clock";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Be a nice person and start with Birthday Countdown Alarm Clock</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Be a nice person and start with Birthday Countdown Alarm Clock</p>";
# 	}
# 	tablecontents += "";
# 	var change = "You also can turn on/off alarm, set alarm time, sound and vibration effects";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>You also can turn on/off alarm, set alarm time, sound and vibration effects</p>";
# 	}
# 	else{
# 	tablecontents += "<p>You also can turn on/off alarm, set alarm time, sound and vibration effects</p>";
# 	}
# 	tablecontents += "";
# 	var change = "You also can have some further operations by long pressing it";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>You also can have some further operations by long pressing it</p>";
# 	}
# 	else{
# 	tablecontents += "<p>You also can have some further operations by long pressing it</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Click to save it and then you will find it in the main interface";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Click to save it and then you will find it in the main interface</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Click to save it and then you will find it in the main interface</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Settings";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Settings</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Settings</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Easy and simple to use";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Easy and simple to use</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Easy and simple to use</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Then you need to deactivate before you uninstall it, otherwise, you cannot uninstall it";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Then you need to deactivate before you uninstall it, otherwise, you cannot uninstall it</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Then you need to deactivate before you uninstall it, otherwise, you cannot uninstall it</p>";
# 	}
# 	tablecontents += "";
# 	var change = "The things in this application are around with birthday";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>The things in this application are around with birthday</p>";
# 	}
# 	else{
# 	tablecontents += "<p>The things in this application are around with birthday</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Base on android mobile operating system";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Base on android mobile operating system</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Base on android mobile operating system</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Birthday is a day that a person celebrates the anniversary of his or her birth";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Birthday is a day that a person celebrates the anniversary of his or her birth</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Birthday is a day that a person celebrates the anniversary of his or her birth</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Calculate way and date format can be chose in this section, and various options are provided by Birthday Countdown Alarm Clock";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Calculate way and date format can be chose in this section, and various options are provided by Birthday Countdown Alarm Clock</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Calculate way and date format can be chose in this section, and various options are provided by Birthday Countdown Alarm Clock</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Find this app there and uncheck to uninstall";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Find this app there and uncheck to uninstall</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Find this app there and uncheck to uninstall</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Functions introduction";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Functions introduction</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Functions introduction</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Main interface";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Main interface</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Main interface</p>";
# 	}
# 	tablecontents += "";
# 	var change = "It is also ad-supported which means that you may find icon ads or notification ads in this app(RECEIVE_BOOT_COMPLETED)";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>It is also ad-supported which means that you may find icon ads or notification ads in this app(RECEIVE_BOOT_COMPLETED)</p>";
# 	}
# 	else{
# 	tablecontents += "<p>It is also ad-supported which means that you may find icon ads or notification ads in this app(RECEIVE_BOOT_COMPLETED)</p>";
# 	}
# 	tablecontents += "";
# 	var change = "This app can be activated by the inside setting button";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>This app can be activated by the inside setting button</p>";
# 	}
# 	else{
# 	tablecontents += "<p>This app can be activated by the inside setting button</p>";
# 	}
# 	tablecontents += "";
# 	var change = "This application is used to help you to remember the birthday of people who important for you, and it will remind you when the birthday comes(READ_CONTACTS)";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>This application is used to help you to remember the birthday of people who important for you, and it will remind you when the birthday comes(READ_CONTACTS)</p>";
# 	}
# 	else{
# 	tablecontents += "<p>This application is used to help you to remember the birthday of people who important for you, and it will remind you when the birthday comes(READ_CONTACTS)</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Download this app and you will find them out";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Download this app and you will find them out</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Download this app and you will find them out</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Enter into the information, including name, description and birthday";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Enter into the information, including name, description and birthday</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Enter into the information, including name, description and birthday</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Information for person&#39;s birthday";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Information for person&#39;s birthday</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Information for person&#39;s birthday</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Now, download it";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Now, download it</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Now, download it</p>";
# 	}
# 	tablecontents += "";
# 	var change = "About Uninstall";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>About Uninstall</p>";
# 	}
# 	else{
# 	tablecontents += "<p>About Uninstall</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Menu";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Menu</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Menu</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Thanks for your understanding";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Thanks for your understanding</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Thanks for your understanding</p>";
# 	}
# 	tablecontents += "";
# 	var change = "With this free app, maybe you can make yourself more popular among your friends";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>With this free app, maybe you can make yourself more popular among your friends</p>";
# 	}
# 	else{
# 	tablecontents += "<p>With this free app, maybe you can make yourself more popular among your friends</p>";
# 	}
# 	tablecontents += "";
# 	var change = "Features";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>Features</p>";
# 	}
# 	else{
# 	tablecontents += "<p>Features</p>";
# 	}
# 	tablecontents += "";
# 	var change = "setting";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>setting</p>";
# 	}
# 	else{
# 	tablecontents += "<p>setting</p>";
# 	}
# 	tablecontents += "";
# 	var change = "You can click them here to check the detail information for the day of his/her birthday, such as will be age, week day and zodiac sign and so on";
# 	if((change.indexOf(")")!=-1 && change.indexOf("(")!=-1 && change.indexOf("_")!=-1)||change.indexOf("CAMERA")!=-1){
# 	tablecontents += "<p class='turn_green'>You can click them here to check the detail information for the day of his/her birthday, such as will be age, week day and zodiac sign and so on</p>";
# 	}
# 	else{
# 	tablecontents += "<p>You can click them here to check the detail information for the day of his/her birthday, such as will be age, week day and zodiac sign and so on</p>";
# 	}
# 	tablecontents += "";
# 	tablecontents += "</td>";
# 	tablecontents += "</tr>";
#
# 	}
#
# 	tablecontents += "";
#
#
# 	tablecontents += "</table>";
# 	document.getElementById("tablespace").innerHTML = tablecontents;
# 	}

# %%
import re

# %%
# match = re.match(r'^<p [\w]+>', '<p class="123">')
match = re.compile(r'^<p\s*.*|>(.*)</p>')

# %%
# lists = re.findall(match, 'asdfasfas<p class="123">asdfasdfsda</p>asdasd')
lists = re.findall(match, ps)
lists = list(set(lists))

# %%
import pandas as pd
lists = pd.DataFrame(lists)
lists.T
# help(pd.to_csv())
# Out:
#                                           0                              1   \
# 0  Click the following buttons to deactivate  Thanks for your understanding
#
#                                                   2                       3   \
# 0  Birthday is a day that a person celebrates the...  Easy and simple to use
#
#      4               5                      6                       7   \
# 0  Menu  Main interface  device administration  Functions introduction
#
#                                                   8   \
# 0  With this free app, maybe you can make yoursel...
#
#                                                   9   \
# 0  You can click them here to check the detail in...
#
#                          ...                          \
# 0                        ...
#
#                                         29  \
# 0  Base on android mobile operating system
#
#                                                   30        31  \
# 0  How to remember the person&#39;s birthday thou...  Features
#
#                                                   32  \
# 0  This application is used to help you to rememb...
#
#                                                   33  \
# 0  It will show you the person&#39;s name, and le...
#
#                                              34                        35  \
# 0  Download this app and you will find them out  Alarm clock for birthday
#
#                                                   36  \
# 0  Then you need to deactivate before you uninsta...
#
#                                                   37  \
# 0  Enter into the information, including name, de...
#
#                                                   38
# 0  It is also ad-supported which means that you m...
#
# [1 rows x 39 columns]

# %%
lists.T.to_csv('test.csv')

# %%
import os
import os.path
rootdir = '.'

filename_list = []
for parent, dirnames, filenames in os.walk(rootdir):
    for filename in filenames:                        #输出文件信息
        filename_list.append(filename)

# %%
import re
txt = re.compile(r'.*.txt')
f_list = []
for f in filename_list:
    if txt.match(f):
        f_list.append(f)

f_list
# Out:
# ['bad_read_calendar.txt',
#  'bad_read_contact.txt',
#  'bad_record_audio.txt',
#  'good_read_calendar.txt',
#  'good_read_contact.txt',
#  'good_record_audio.txt']

# %%
import pandas as pd
match = re.compile(r'^<p\s*.*|>(.*)</p>')
for fname in f_list[:1]:
    f = open(fname, 'r')
    line = f.readline()
    list_all = []
    while(line):
        url = 'http://webportal2-autocog.rhcloud.com/search/?q=' + str(line)
        soup = crawl(url)
        ps = soup.find('script', type='text/javascript').get_text()
        lists = re.findall(match, ps)
        lists = list(set(lists))
        list_all.append(lists)
        line = f.readline()
    
    lists = pd.DataFrame(lists_all)
    lists.T.to_csv(str(fname) + '.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-44f76267726e> in <module>()
#       7     while(line):
#       8         url = 'http://webportal2-autocog.rhcloud.com/search/?q=' + str(line)
# ----> 9         soup = crawl(url)
#      10         ps = soup.find('script', type='text/javascript').get_text()
#      11         lists = re.findall(match, ps)
#
# <ipython-input-18-a7960ff4f504> in crawl(url)
#      11     headers = {'User-Agent': user_agent}
#      12     request = urllib2.Request(url, headers=headers)
# ---> 13     response = urllib2.urlopen(request)
#      14     html = response.read()
#      15     soup = BeautifulSoup(html, from_encoding='utf-8')
#
# C:\Program Files\Anaconda2\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\Program Files\Anaconda2\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# C:\Program Files\Anaconda2\lib\urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# C:\Program Files\Anaconda2\lib\urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# C:\Program Files\Anaconda2\lib\urllib2.pyc in http_open(self, req)
#    1226
#    1227     def http_open(self, req):
# -> 1228         return self.do_open(httplib.HTTPConnection, req)
#    1229
#    1230     http_request = AbstractHTTPHandler.do_request_
#
# C:\Program Files\Anaconda2\lib\urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1199         else:
#    1200             try:
# -> 1201                 r = h.getresponse(buffering=True)
#    1202             except TypeError: # buffering kw not supported
#    1203                 r = h.getresponse()
#
# C:\Program Files\Anaconda2\lib\httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# C:\Program Files\Anaconda2\lib\httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# C:\Program Files\Anaconda2\lib\httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# C:\Program Files\Anaconda2\lib\socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:
